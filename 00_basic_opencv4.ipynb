# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammad-Rakibuzzaman/opencv-ipynb/blob/main/00_basic_opencv4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.10.0

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
image = cv2.imread('/content/bleed.jpg')

# %%
from matplotlib import pyplot as plt

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
def imshow(title = "", image = None):
  plt.imshow(image)
  plt.title(title)
  plt.show()

# %%
new = imshow("Displaying my wifu image", image)

# %%
news = cv2.imread(new)

# %%
# plt.imshow(cv2.cvtColor(news, cv2.COLOR_BGR2RGB))
# plt.show()

# %%
cv2.imwrite('outputmy.jpg', image)
# Out:
# True

# %%
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
cv2.imwrite('output.png', image)
# Out:
# True

# %%
import numpy as np

print(image.shape)
# Out:
# (736, 736, 3)

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 736 pixels
# Width of Image: 736 pixels
# Depth of Image: 3 colors components
